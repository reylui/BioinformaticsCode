# %% [markdown]
# #### Analyzing a microbiome

# %%
from pandas import read_csv
from seaborn import clustermap
from os import listdir
from IPython.display import HTML

# %%
print("Files in the working directory:",listdir())
# Out:
# Files in the working directory: ['.git', '.idea', '.ipynb_checkpoints', '.vs', 'Microbiome Analysis - basics.ipynb', 'PythonProblems1.ipynb', 'README.md']

# %%
# note that \t is a special character indicating a tab
#sep stands for 'separator'
#csv stands for 'comma-separated values' - a text version of an excel file
feature_table = read_csv('scenario1_otus_pandas.txt',sep="\t")
HTML(feature_table.to_html())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-24c4c7580e7e> in <module>()
#       2 #sep stands for 'separator'
#       3 #csv stands for 'comma-separated values' - a text version of an excel file
# ----> 4 feature_table = read_csv('scenario1_otus_pandas.txt',sep="\t")
#       5 HTML(feature_table.to_html())
#
# C:\Users\LuisJ\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\Users\LuisJ\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# C:\Users\LuisJ\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\Users\LuisJ\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# C:\Users\LuisJ\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'scenario1_otus_pandas.txt' does not exist: b'scenario1_otus_pandas.txt'

# %%
feature_table = feature_table.set_index('OTU_ID')
clustermap(feature_table)

# %%
clustermap(feature_table.transpose())
